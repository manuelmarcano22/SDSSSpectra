# %% [markdown]
# # Sloan Extension for Galactic Understanding and Exploration (SEGUE)
#
#
# ## [SEGUE: Mapping the Outer Milky Way](http://www.sdss.org/surveys/segue/)

# %% [markdown]
# Paper:
#      [SEGUE: A Spectroscopic Survey of 240,000 stars with g=14-20](https://arxiv.org/abs/0902.1781)
#
# Datamodels:
#
#
# 1- [ssppOut](https://data.sdss.org/datamodel/files/SSPP_REDUX/ssppOut.html). This file consolidates the ssppOut results from the SSPP pipeline for all plates associated with a given data release.
#
# 2- [individual ssppOut](https://data.sdss.org/datamodel/files/SSPP_REDUX/ssppOut.html)
#
#
# ## [Flags in SSPP](http://www.sdss.org/dr14/spectro/sspp_flags/)
#
# > The nominal condition for the five letter flag combination is `nnnnn’, which indicates that the SSPP is satisfied that a given stellar spectrum (and its reported g-r colors and S/N) has passed all of the tests that have been performed, and the stellar parameters should be considered well determined.

# %%
# Require packages
from astropy.io import fits
import os

# %%
if not os.path.isfile('ssppOut-dr12.fits'):
    ! wget https://data.sdss.org/sas/dr14/sdss/sspp/ssppOut-dr12.fits
sspp = fits.open('ssppOut-dr12.fits',memmap=True)
data = sspp[1].data
print('Length of data: '+str(len(data)))
sspp[1].header
# Out:
# Length of data: 1843200
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                 1038 /Number of bytes per row
# NAXIS2  =              1843200 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                  239 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'SPECOBJID'          /
# TTYPE2  = 'PLATEID '           /
# TTYPE3  = 'BESTOBJID'          /
# TTYPE4  = 'FLUXOBJID'          /
# TTYPE5  = 'TARGETOBJID'        /
# TTYPE6  = 'SPECPRIMARY'        /
# TTYPE7  = 'SPECLEGACY'         /
# TTYPE8  = 'SPECSEGUE'          /
# TTYPE9  = 'SPECSEGUE1'         /
# TTYPE10 = 'SPECSEGUE2'         /
# TTYPE11 = 'PLUG_RA '           /
# TTYPE12 = 'PLUG_DEC'           /
# TTYPE13 = 'LEGACY_TARGET1'     /
# TTYPE14 = 'LEGACY_TARGET2'     /
# TTYPE15 = 'SPECIAL_TARGET1'    /
# TTYPE16 = 'SPECIAL_TARGET2'    /
# TTYPE17 = 'FIRSTRELEASE'       /
# TTYPE18 = 'PROGRAMNAME'        /
# TTYPE19 = 'CHUNK   '           /
# TTYPE20 = 'PLATERUN'           /
# TTYPE21 = 'RUNSSPP '           /
# TTYPE22 = 'RUN1D   '           /
# TTYPE23 = 'RUN2D   '           /
# TTYPE24 = 'MJD     '           /
# TTYPE25 = 'PLATE   '           /
# TTYPE26 = 'FIBER   '           /
# TTYPE27 = 'PRIM_TARGET'        /
# TTYPE28 = 'SPECTYPE_HAMMER'    /
# TTYPE29 = 'SPECTYPE_SUBCLASS'  /
# TTYPE30 = 'FLAG    '           /
# TTYPE31 = 'TEFF_ADOP'          /
# TTYPE32 = 'TEFF_ADOP_N'        /
# TTYPE33 = 'TEFF_ADOP_UNC'      /
# TTYPE34 = 'TEFF_HA24'          /
# TTYPE35 = 'TEFF_HD24'          /
# TTYPE36 = 'TEFF_TK '           /
# TTYPE37 = 'TEFF_TG '           /
# TTYPE38 = 'TEFF_TI '           /
# TTYPE39 = 'TEFF_NGS1'          /
# TTYPE40 = 'TEFF_ANNSR'         /
# TTYPE41 = 'TEFF_ANNRR'         /
# TTYPE42 = 'TEFF_WBG'           /
# TTYPE43 = 'TEFF_K24'           /
# TTYPE44 = 'TEFF_KI13'          /
# TTYPE45 = 'TEFF_HA24_IND'      /
# TTYPE46 = 'TEFF_HD24_IND'      /
# TTYPE47 = 'TEFF_TK_IND'        /
# TTYPE48 = 'TEFF_TG_IND'        /
# TTYPE49 = 'TEFF_TI_IND'        /
# TTYPE50 = 'TEFF_NGS1_IND'      /
# TTYPE51 = 'TEFF_ANNSR_IND'     /
# TTYPE52 = 'TEFF_ANNRR_IND'     /
# TTYPE53 = 'TEFF_WBG_IND'       /
# TTYPE54 = 'TEFF_K24_IND'       /
# TTYPE55 = 'TEFF_KI13_IND'      /
# TTYPE56 = 'TEFF_HA24_UNC'      /
# TTYPE57 = 'TEFF_HD24_UNC'      /
# TTYPE58 = 'TEFF_TK_UNC'        /
# TTYPE59 = 'TEFF_TG_UNC'        /
# TTYPE60 = 'TEFF_TI_UNC'        /
# TTYPE61 = 'TEFF_NGS1_UNC'      /
# TTYPE62 = 'TEFF_ANNSR_UNC'     /
# TTYPE63 = 'TEFF_ANNRR_UNC'     /
# TTYPE64 = 'TEFF_WBG_UNC'       /
# TTYPE65 = 'TEFF_K24_UNC'       /
# TTYPE66 = 'TEFF_KI13_UNC'      /
# TTYPE67 = 'LOGG_ADOP'          /
# TTYPE68 = 'LOGG_ADOP_N'        /
# TTYPE69 = 'LOGG_ADOP_UNC'      /
# TTYPE70 = 'LOGG_NGS2'          /
# TTYPE71 = 'LOGG_NGS1'          /
# TTYPE72 = 'LOGG_ANNSR'         /
# TTYPE73 = 'LOGG_ANNRR'         /
# TTYPE74 = 'LOGG_CAI1'          /
# TTYPE75 = 'LOGG_CAI2'          /
# TTYPE76 = 'LOGG_MGH'           /
# TTYPE77 = 'LOGG_WBG'           /
# TTYPE78 = 'LOGG_K24'           /
# TTYPE79 = 'LOGG_KI13'          /
# TTYPE80 = 'LOGG_NGS2_IND'      /
# TTYPE81 = 'LOGG_NGS1_IND'      /
# TTYPE82 = 'LOGG_ANNSR_IND'     /
# TTYPE83 = 'LOGG_ANNRR_IND'     /
# TTYPE84 = 'LOGG_CAI1_IND'      /
# TTYPE85 = 'LOGG_CAI2_IND'      /
# TTYPE86 = 'LOGG_MGH_IND'       /
# TTYPE87 = 'LOGG_WBG_IND'       /
# TTYPE88 = 'LOGG_K24_IND'       /
# TTYPE89 = 'LOGG_KI13_IND'      /
# TTYPE90 = 'LOGG_NGS2_UNC'      /
# TTYPE91 = 'LOGG_NGS1_UNC'      /
# TTYPE92 = 'LOGG_ANNSR_UNC'     /
# TTYPE93 = 'LOGG_ANNRR_UNC'     /
# TTYPE94 = 'LOGG_CAI1_UNC'      /
# TTYPE95 = 'LOGG_CAI2_UNC'      /
# TTYPE96 = 'LOGG_MGH_UNC'       /
# TTYPE97 = 'LOGG_WBG_UNC'       /
# TTYPE98 = 'LOGG_K24_UNC'       /
# TTYPE99 = 'LOGG_KI13_UNC'      /
# TTYPE100= 'FEH_ADOP'           /
# TTYPE101= 'FEH_ADOP_N'         /
# TTYPE102= 'FEH_ADOP_UNC'       /
# TTYPE103= 'FEH_NGS2'           /
# TTYPE104= 'FEH_NGS1'           /
# TTYPE105= 'FEH_ANNSR'          /
# TTYPE106= 'FEH_ANNRR'          /
# TTYPE107= 'FEH_CAIIK1'         /
# TTYPE108= 'FEH_CAIIK2'         /
# TTYPE109= 'FEH_CAIIK3'         /
# TTYPE110= 'FEH_ACF '           /
# TTYPE111= 'FEH_CAIIT'          /
# TTYPE112= 'FEH_WBG '           /
# TTYPE113= 'FEH_K24 '           /
# TTYPE114= 'FEH_KI13'           /
# TTYPE115= 'FEH_NGS2_IND'       /
# TTYPE116= 'FEH_NGS1_IND'       /
# TTYPE117= 'FEH_ANNSR_IND'      /
# TTYPE118= 'FEH_ANNRR_IND'      /
# TTYPE119= 'FEH_CAIIK1_IND'     /
# TTYPE120= 'FEH_CAIIK2_IND'     /
# TTYPE121= 'FEH_CAIIK3_IND'     /
# TTYPE122= 'FEH_ACF_IND'        /
# TTYPE123= 'FEH_CAIIT_IND'      /
# TTYPE124= 'FEH_WBG_IND'        /
# TTYPE125= 'FEH_K24_IND'        /
# TTYPE126= 'FEH_KI13_IND'       /
# TTYPE127= 'FEH_NGS2_UNC'       /
# TTYPE128= 'FEH_NGS1_UNC'       /
# TTYPE129= 'FEH_ANNSR_UNC'      /
# TTYPE130= 'FEH_ANNRR_UNC'      /
# TTYPE131= 'FEH_CAIIK1_UNC'     /
# TTYPE132= 'FEH_CAIIK2_UNC'     /
# TTYPE133= 'FEH_CAIIK3_UNC'     /
# TTYPE134= 'FEH_ACF_UNC'        /
# TTYPE135= 'FEH_CAIIT_UNC'      /
# TTYPE136= 'FEH_WBG_UNC'        /
# TTYPE137= 'FEH_K24_UNC'        /
# TTYPE138= 'FEH_KI13_UNC'       /
# TTYPE139= 'AFE     '           /
# TTYPE140= 'AFE_IND '           /
# TTYPE141= 'AFE_UNC '           /
# TTYPE142= 'DIST_DWARF'         /
# TTYPE143= 'DIST_TO '           /
# TTYPE144= 'DIST_GIANT'         /
# TTYPE145= 'DIST_AGB'           /
# TTYPE146= 'DIST_FHB'           /
# TTYPE147= 'DIST_AP '           /
# TTYPE148= 'DIST_Z  '           /
# TTYPE149= 'RV_FLAG '           /
# TTYPE150= 'RV_ADOP '           /
# TTYPE151= 'RV_ADOP_UNC'        /
# TTYPE152= 'RV_CAL  '           /
# TTYPE153= 'RV_CAL_UNC'         /
# TTYPE154= 'RV_BS   '           /
# TTYPE155= 'RV_BS_UNC'          /
# TTYPE156= 'RV_ELODIE'          /
# TTYPE157= 'RV_ELODIE_UNC'      /
# TTYPE158= 'RV_GSR  '           /
# TTYPE159= 'RV_GSR_UNC'         /
# TTYPE160= 'V_MAG   '           /
# TTYPE161= 'BV      '           /
# TTYPE162= 'BV_BALMER'          /
# TTYPE163= 'GR_PREDICT'         /
# TTYPE164= 'GR_HA24 '           /
# TTYPE165= 'GR_HD24 '           /
# TTYPE166= 'GR_HP   '           /
# TTYPE167= 'G_MAG   '           /
# TTYPE168= 'UG      '           /
# TTYPE169= 'GR      '           /
# TTYPE170= 'RI      '           /
# TTYPE171= 'IZ      '           /
# TTYPE172= 'U_MAG_UNC'          /
# TTYPE173= 'G_MAG_UNC'          /
# TTYPE174= 'R_MAG_UNC'          /
# TTYPE175= 'I_MAG_UNC'          /
# TTYPE176= 'Z_MAG_UNC'          /
# TTYPE177= 'EBV     '           /
# TTYPE178= 'SNR     '           /
# TTYPE179= 'QA      '           /
# TTYPE180= 'CC_CAHK '           /
# TTYPE181= 'CC_MGH  '           /
# TTYPE182= 'RA      '           /
# TTYPE183= 'DEC     '           /
# TTYPE184= 'L       '           /
# TTYPE185= 'B       '           /
# TTYPE186= 'TEFF_SPEC'          /
# TTYPE187= 'TEFF_SPEC_N'        /
# TTYPE188= 'TEFF_SPEC_UNC'      /
# TTYPE189= 'LOGG_SPEC'          /
# TTYPE190= 'LOGG_SPEC_N'        /
# TTYPE191= 'LOGG_SPEC_UNC'      /
# TTYPE192= 'FEH_SPEC'           /
# TTYPE193= 'FEH_SPEC_N'         /
# TTYPE194= 'FEH_SPEC_UNC'       /
# TTYPE195= 'TEFF_COL'           /
# TTYPE196= 'TEFF_COL_UNC'       /
# TTYPE197= 'FEH_TFIX_NGS2'      /
# TTYPE198= 'FEH_TFIX_NGS1'      /
# TTYPE199= 'LOGG_TFIX_NGS2'     /
# TTYPE200= 'LOGG_TFIX_NGS1'     /
# TTYPE201= 'FEH_TFIX_NGS2_UNC'  /
# TTYPE202= 'FEH_TFIX_NGS1_UNC'  /
# TTYPE203= 'LOGG_TFIX_NGS2_UNC' /
# TTYPE204= 'LOGG_TFIX_NGS1_UNC' /
# TTYPE205= 'FEH_TFIX_CAIIK1'    /
# TTYPE206= 'FEH_TFIX_CAIIK1_UNC' /
# TTYPE207= 'ACF1    '           /
# TTYPE208= 'ACF1_SNR'           /
# TTYPE209= 'ACF2    '           /
# TTYPE210= 'ACF2_SNR'           /
# TTYPE211= 'INSPECT '           /
# TTYPE212= 'ELODIERVFINAL'      /
# TTYPE213= 'ELODIERVFINALERR'   /
# TTYPE214= 'ZWARNING'           /
# TTYPE215= 'SURVEY  '           /
# TTYPE216= 'PRIMTARGET'         /
# TTYPE217= 'SECTARGET'          /
# TTYPE218= 'SEGUE1_TARGET1'     /
# TTYPE219= 'SEGUE1_TARGET2'     /
# TTYPE220= 'SEGUE2_TARGET1'     /
# TTYPE221= 'SEGUE2_TARGET2'     /
# TTYPE222= 'L_CLASS '           /
# TTYPE223= 'DIST_ADOP'          /
# TTYPE224= 'MP_FLAG '           /
# TTYPE225= 'TEFF_IRFM'          /
# TTYPE226= 'TEFF_IRFM_IND'      /
# TTYPE227= 'TEFF_IRFM_UNC'      /
# TTYPE228= 'LOGG_NGS1_IRFM'     /
# TTYPE229= 'LOGG_NGS1_IRFM_IND' /
# TTYPE230= 'LOGG_NGS1_IRFM_UNC' /
# TTYPE231= 'FEH_NGS1_IRFM'      /
# TTYPE232= 'FEH_NGS1_IRFM_IND'  /
# TTYPE233= 'FEH_NGS1_IRFM_UNC'  /
# TTYPE234= 'LOGG_CAI1_IRFM'     /
# TTYPE235= 'LOGG_CAI1_IRFM_IND' /
# TTYPE236= 'LOGG_CAI1_IRFM_UNC' /
# TTYPE237= 'FEH_CAIIK1_IRFM'    /
# TTYPE238= 'FEH_CAIIK1_IRFM_IND' /
# TTYPE239= 'FEH_CAIIK1_IRFM_UNC' /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '22A     '           /
# TFORM2  = '19A     '           /
# TFORM3  = '19A     '           /
# TFORM4  = '19A     '           /
# TFORM5  = '22A     '           /
# TFORM6  = 'J       '           /
# TFORM7  = 'J       '           /
# TFORM8  = 'J       '           /
# TFORM9  = 'J       '           /
# TFORM10 = 'J       '           /
# TFORM11 = 'D       '           /
# TFORM12 = 'D       '           /
# TFORM13 = 'J       '           /
# TFORM14 = 'J       '           /
# TFORM15 = 'K       '           /
# TFORM16 = 'K       '           /
# TFORM17 = '3A      '           /
# TFORM18 = '23A     '           /
# TFORM19 = '16A     '           /
# TFORM20 = '16A     '           /
# TFORM21 = '3A      '           /
# TFORM22 = 'A       '           /
# TFORM23 = '3A      '           /
# TFORM24 = 'J       '           /
# TFORM25 = 'I       '           /
# TFORM26 = 'I       '           /
# TFORM27 = '13A     '           /
# TFORM28 = '4A      '           /
# TFORM29 = '20A     '           /
# TFORM30 = '5A      '           /
# TFORM31 = 'E       '           /
# TFORM32 = 'I       '           /
# TFORM33 = 'E       '           /
# TFORM34 = 'E       '           /
# TFORM35 = 'E       '           /
# TFORM36 = 'E       '           /
# TFORM37 = 'E       '           /
# TFORM38 = 'E       '           /
# TFORM39 = 'E       '           /
# TFORM40 = 'E       '           /
# TFORM41 = 'E       '           /
# TFORM42 = 'E       '           /
# TFORM43 = 'E       '           /
# TFORM44 = 'E       '           /
# TFORM45 = 'I       '           /
# TFORM46 = 'I       '           /
# TFORM47 = 'I       '           /
# TFORM48 = 'I       '           /
# TFORM49 = 'I       '           /
# TFORM50 = 'I       '           /
# TFORM51 = 'I       '           /
# TFORM52 = 'I       '           /
# TFORM53 = 'I       '           /
# TFORM54 = 'I       '           /
# TFORM55 = 'I       '           /
# TFORM56 = 'E       '           /
# TFORM57 = 'E       '           /
# TFORM58 = 'E       '           /
# TFORM59 = 'E       '           /
# TFORM60 = 'E       '           /
# TFORM61 = 'E       '           /
# TFORM62 = 'E       '           /
# TFORM63 = 'E       '           /
# TFORM64 = 'E       '           /
# TFORM65 = 'E       '           /
# TFORM66 = 'E       '           /
# TFORM67 = 'E       '           /
# TFORM68 = 'I       '           /
# TFORM69 = 'E       '           /
# TFORM70 = 'E       '           /
# TFORM71 = 'E       '           /
# TFORM72 = 'E       '           /
# TFORM73 = 'E       '           /
# TFORM74 = 'E       '           /
# TFORM75 = 'E       '           /
# TFORM76 = 'E       '           /
# TFORM77 = 'E       '           /
# TFORM78 = 'E       '           /
# TFORM79 = 'E       '           /
# TFORM80 = 'I       '           /
# TFORM81 = 'I       '           /
# TFORM82 = 'I       '           /
# TFORM83 = 'I       '           /
# TFORM84 = 'I       '           /
# TFORM85 = 'I       '           /
# TFORM86 = 'I       '           /
# TFORM87 = 'I       '           /
# TFORM88 = 'I       '           /
# TFORM89 = 'I       '           /
# TFORM90 = 'E       '           /
# TFORM91 = 'E       '           /
# TFORM92 = 'E       '           /
# TFORM93 = 'E       '           /
# TFORM94 = 'E       '           /
# TFORM95 = 'E       '           /
# TFORM96 = 'E       '           /
# TFORM97 = 'E       '           /
# TFORM98 = 'E       '           /
# TFORM99 = 'E       '           /
# TFORM100= 'E       '           /
# TFORM101= 'I       '           /
# TFORM102= 'E       '           /
# TFORM103= 'E       '           /
# TFORM104= 'E       '           /
# TFORM105= 'E       '           /
# TFORM106= 'E       '           /
# TFORM107= 'E       '           /
# TFORM108= 'E       '           /
# TFORM109= 'E       '           /
# TFORM110= 'E       '           /
# TFORM111= 'E       '           /
# TFORM112= 'E       '           /
# TFORM113= 'E       '           /
# TFORM114= 'E       '           /
# TFORM115= 'I       '           /
# TFORM116= 'I       '           /
# TFORM117= 'I       '           /
# TFORM118= 'I       '           /
# TFORM119= 'I       '           /
# TFORM120= 'I       '           /
# TFORM121= 'I       '           /
# TFORM122= 'I       '           /
# TFORM123= 'I       '           /
# TFORM124= 'I       '           /
# TFORM125= 'I       '           /
# TFORM126= 'I       '           /
# TFORM127= 'E       '           /
# TFORM128= 'E       '           /
# TFORM129= 'E       '           /
# TFORM130= 'E       '           /
# TFORM131= 'E       '           /
# TFORM132= 'E       '           /
# TFORM133= 'E       '           /
# TFORM134= 'E       '           /
# TFORM135= 'E       '           /
# TFORM136= 'E       '           /
# TFORM137= 'E       '           /
# TFORM138= 'E       '           /
# TFORM139= 'E       '           /
# TFORM140= 'I       '           /
# TFORM141= 'E       '           /
# TFORM142= 'E       '           /
# TFORM143= 'E       '           /
# TFORM144= 'E       '           /
# TFORM145= 'E       '           /
# TFORM146= 'E       '           /
# TFORM147= 'E       '           /
# TFORM148= 'E       '           /
# TFORM149= '4A      '           /
# TFORM150= 'E       '           /
# TFORM151= 'E       '           /
# TFORM152= 'E       '           /
# TFORM153= 'E       '           /
# TFORM154= 'E       '           /
# TFORM155= 'E       '           /
# TFORM156= 'E       '           /
# TFORM157= 'E       '           /
# TFORM158= 'E       '           /
# TFORM159= 'E       '           /
# TFORM160= 'E       '           /
# TFORM161= 'E       '           /
# TFORM162= 'E       '           /
# TFORM163= 'E       '           /
# TFORM164= 'E       '           /
# TFORM165= 'E       '           /
# TFORM166= 'E       '           /
# TFORM167= 'E       '           /
# TFORM168= 'E       '           /
# TFORM169= 'E       '           /
# TFORM170= 'E       '           /
# TFORM171= 'E       '           /
# TFORM172= 'E       '           /
# TFORM173= 'E       '           /
# TFORM174= 'E       '           /
# TFORM175= 'E       '           /
# TFORM176= 'E       '           /
# TFORM177= 'E       '           /
# TFORM178= 'E       '           /
# TFORM179= 'I       '           /
# TFORM180= 'E       '           /
# TFORM181= 'E       '           /
# TFORM182= 'D       '           /
# TFORM183= 'D       '           /
# TFORM184= 'D       '           /
# TFORM185= 'D       '           /
# TFORM186= 'E       '           /
# TFORM187= 'I       '           /
# TFORM188= 'E       '           /
# TFORM189= 'E       '           /
# TFORM190= 'I       '           /
# TFORM191= 'E       '           /
# TFORM192= 'E       '           /
# TFORM193= 'I       '           /
# TFORM194= 'E       '           /
# TFORM195= 'E       '           /
# TFORM196= 'E       '           /
# TFORM197= 'E       '           /
# TFORM198= 'E       '           /
# TFORM199= 'E       '           /
# TFORM200= 'E       '           /
# TFORM201= 'E       '           /
# TFORM202= 'E       '           /
# TFORM203= 'E       '           /
# TFORM204= 'E       '           /
# TFORM205= 'E       '           /
# TFORM206= 'E       '           /
# TFORM207= 'E       '           /
# TFORM208= 'E       '           /
# TFORM209= 'E       '           /
# TFORM210= 'E       '           /
# TFORM211= '6A      '           /
# TFORM212= 'E       '           /
# TFORM213= 'E       '           /
# TFORM214= 'J       '           /
# TFORM215= '6A      '           /
# TFORM216= 'J       '           /
# TFORM217= 'J       '           /
# TFORM218= 'J       '           /
# TFORM219= 'J       '           /
# TFORM220= 'J       '           /
# TFORM221= 'J       '           /
# TFORM222= '4A      '           /
# TFORM223= 'E       '           /
# TFORM224= '2A      '           /
# TFORM225= 'E       '           /
# TFORM226= 'I       '           /
# TFORM227= 'E       '           /
# TFORM228= 'E       '           /
# TFORM229= 'I       '           /
# TFORM230= 'E       '           /
# TFORM231= 'E       '           /
# TFORM232= 'I       '           /
# TFORM233= 'E       '           /
# TFORM234= 'E       '           /
# TFORM235= 'I       '           /
# TFORM236= 'E       '           /
# TFORM237= 'E       '           /
# TFORM238= 'I       '           /
# TFORM239= 'E       '           /

# %%
# %time types = set([ (i[27],i[28],i[29]) for i in data[0:100000] ])  
#Or np.unique([ (i[27],i[28],i[29]) for i in data[0:100000] ],axis=0) and it is sorted.
types
# Out:
# CPU times: user 26.8 s, sys: 44 ms, total: 26.8 s
# Wall time: 26.8 s
# {('  dK', 'M3', 'nnngn'),
#  ('G7', '00', 'VCBnN'),
#  ('G5', 'K1', 'nnBnn'),
#  ('G6', 'G0', 'nnnnn'),
#  ('M0', 'K3', 'nnnGn'),
#  ('K2', 'F9', 'NCBnN'),
#  ('M0', 'K3', 'NnBgn'),
#  ('NA', 'A0', 'nnnGn'),
#  ('G1', 'F2', 'nCnnn'),
#  ('esdK', '00', 'VCnnN'),
#  ('M3', '00', 'VCBnX'),
#  ('K4', 'G2', 'nnnnn'),
#  ('K2', 'F9', 'NCnnN'),
#  (' sdM', 'M0', 'NnnnR'),
#  ('F8', 'F5', 'nCnnN'),
#  ('  dM', '00', 'VnnnN'),
#  ('G9', 'K5', 'NnBnN'),
#  ('  dK', 'M2', 'nnBnn'),
#  ('G3', 'G2', 'nnBnn'),
#  ('K2', '00', 'VnnnX'),
#  ('F2', '00', 'nnBnN'),
#  ('usdM', 'M0V', 'NnnnR'),
#  ('G0', '00', 'VCnnR'),
#  ('esdK', 'T2', 'NCnnN'),
#  ('G1', 'QSO', 'EnnnX'),
#  ('G3', 'F9', 'nnnnn'),
#  ('F9', 'G2', 'nnnnn'),
#  ('K0', 'F9', 'nnnnn'),
#  ('K4', 'M1', 'NnnnN'),
#  ('M2', 'CAR', 'nnnnR'),
#  ('NA', 'M0V', 'NnnnN'),
#  ('M1', '00', 'VnnnX'),
#  ('G9', '00', 'VnBnX'),
#  ('usdK', '00', 'VCBnX'),
#  ('F0', 'CV', 'nnBnN'),
#  ('F1', '00', 'VnnnR'),
#  (' sdK', 'K5', 'NnnnR'),
#  ('M0', 'K5', 'nnnGn'),
#  ('G3', '00', 'VCnnX'),
#  ('M6', 'M7', 'NnnnR'),
#  ('NA', 'AGN', 'VCBnX'),
#  ('NA', 'L5.5', 'nnnnN'),
#  ('M0', 'K5', 'NnnnN'),
#  ('G4', '00', 'VnBnX'),
#  ('esdK', 'K7', 'NCnnR'),
#  ('G5', 'G0', 'NnnnN'),
#  ('F0', '00', 'VnnnN'),
#  ('  dM', 'M5', 'nnnnR'),
#  ('K2', 'G0', 'nnngn'),
#  ('G1', 'F9', 'nnnnn'),
#  ('F8', 'F2', 'nnnnn'),
#  ('K0', 'K3', 'Nnnnn'),
#  ('NA', 'AGN', 'VCnnX'),
#  ('K5', 'K3', 'nCnnn'),
#  ('usdK', 'K5', 'NnnnR'),
#  ('NA', 'K7', 'NCnnR'),
#  ('G8', 'F9', 'nnBgn'),
#  ('NA', 'L1', 'NnnnR'),
#  ('G6', 'O', 'NnBnN'),
#  ('K2', 'CV', 'nnnnX'),
#  ('NA', 'STARFORMINGBROADLINE', 'VCnnX'),
#  ('G3', '00', 'VCBnN'),
#  ('F6', 'F2', 'nnnGn'),
#  ('  dM', 'M0', 'nCBnn'),
#  ('  dM', 'M1', 'DCnnn'),
#  ('NA', 'A0', 'NnBnN'),
#  ('K3', 'K3', 'nnnnn'),
#  ('  dM', 'M0', 'lnnnN'),
#  ('NA', 'M7', 'VCnnR'),
#  ('K4', 'M0', 'nnnnN'),
#  (' sdM', 'M2', 'lnnnR'),
#  ('F5', 'K1', 'NnnnN'),
#  ('NA', 'M9', 'NCBnN'),
#  ('G5', 'F2', 'NnnnN'),
#  ('F9', 'G2', 'nnnnN'),
#  ('  dM', 'M2', 'NnnnR'),
#  ('NA', 'A0', 'hnBnB'),
#  ('F6', 'F5', 'nnnnn'),
#  ('M1', '00', 'VCBnN'),
#  (' sdK', 'M1', 'NnnnR'),
#  ('M1', 'QSO', 'EnnnX'),
#  ('  dM', 'M3', 'NnnnN'),
#  ('K0', 'G2', 'nCnnn'),
#  ('F2', 'F5', 'nnnGn'),
#  ('  dK', 'M0', 'nnnnn'),
#  (' sdK', 'M0', 'NnnnN'),
#  ('NA', 'CV', 'hnBnN'),
#  ('  dM', 'M0', 'NnnnN'),
#  ('G6', 'F2', 'nnngn'),
#  ('G3', 'F5', 'nnBnN'),
#  ('M7', 'M8', 'VCnnR'),
#  ('NA', 'OB', 'hnBnX'),
#  ('K3', 'K3', 'Nnnnn'),
#  ('NA', 'L5', 'NnnnN'),
#  ('NA', '00', 'nnnnN'),
#  ('F7', 'F2', 'nnngn'),
#  ('K3', 'K3', 'NnBnN'),
#  ('  dM', 'M0', 'nCnnR'),
#  ('K7', '00', 'lCnnN'),
#  ('F2', '00', 'VnnnN'),
#  ('NA', 'F5', 'Nnnnc'),
#  ('F8', 'F2', 'nnnnN'),
#  ('G1', '00', 'NnnnN'),
#  ('  dK', '00', 'VCnnR'),
#  ('NA', 'M3', 'nnBnN'),
#  ('  dK', 'QSO', 'EnnnX'),
#  ('M4', '00', 'VCnnN'),
#  ('  dM', 'M4', 'DCnnP'),
#  ('G8', 'G2', 'nCngn'),
#  ('M0', 'K7', 'nCnnn'),
#  ('NA', 'QSO', 'EnnnX'),
#  ('  dM', 'M8', 'nnnnR'),
#  ('NA', '00', 'hnBnN'),
#  ('K4', 'M0V', 'NnBnN'),
#  ('NA', 'SBT', 'EnnnX'),
#  ('  dK', 'K7', 'lnnnR'),
#  ('G7', '00', 'VCnnR'),
#  ('esdM', 'M0V', 'NCnnN'),
#  ('K7', 'QSO', 'EnnnX'),
#  ('NA', 'K1', 'hnnnN'),
#  ('G8', 'F9', 'NnBnN'),
#  ('  dM', 'M3', 'nCnnR'),
#  ('NA', '00', 'NnBnN'),
#  ('F5', 'F9', 'nnnnn'),
#  ('  dM', '00', 'nnBnn'),
#  ('  dK', '00', 'NnnnN'),
#  ('M8', 'M7', 'NCnnR'),
#  ('  dM', 'M0', 'lnnnn'),
#  ('K2', 'G2', 'nnngn'),
#  ('NA', 'AGNBROADLINE', 'lnnnX'),
#  ('NA', 'K3', 'NCnnN'),
#  ('NA', '00', 'VnnnR'),
#  ('  dK', 'K7', 'NCnnN'),
#  ('K4', 'K1', 'nCnnn'),
#  ('  dK', 'K7', 'NnnnR'),
#  ('NA', 'M4', 'NCnnN'),
#  ('K4', '00', 'nnBnX'),
#  ('F5', 'F5', 'nnBnn'),
#  ('F6', 'F5', 'nnnnN'),
#  ('NA', 'M7', 'NCnnR'),
#  ('K4', 'K5', 'nnnGn'),
#  ('K4', 'K5', 'Nnnnn'),
#  (' sdK', 'K7', 'nCnnR'),
#  ('F4', '00', 'VnBnN'),
#  ('NA', 'L5.5', 'hnnnN'),
#  ('K2', 'Carbon_lines', 'Nnnnc'),
#  ('  dK', 'M0', 'nnnnN'),
#  ('M2', '00', 'VnBnX'),
#  ('M0', '00', 'NnBnN'),
#  ('M1', 'F9', 'NnnnN'),
#  ('NA', 'M6', 'NCnnR'),
#  ('M0', '00', 'VnnnX'),
#  ('esdK', 'M0V', 'lCnnR'),
#  ('  dM', 'M3', 'NCnnN'),
#  ('NA', 'M7', 'NnnnR'),
#  ('K3', 'K3', 'NnnnN'),
#  ('  dK', 'K7', 'nCnnP'),
#  ('K4', '00', 'VCnnN'),
#  ('NA', 'M2', 'nnBnB'),
#  ('NA', 'F2', 'nnnnc'),
#  ('M6', '00', 'VnBnN'),
#  ('F9', 'F5', 'nnBgn'),
#  ('NA', 'F9', 'NnBnN'),
#  ('NA', 'M8', 'NCnnN'),
#  ('G7', 'G2', 'nnnnn'),
#  ('K4', 'M0', 'NnBnN'),
#  ('M2', 'K5', 'NnnnN'),
#  ('G4', 'G2', 'NnnnN'),
#  ('K2', '00', 'nnBnN'),
#  ('K0', '00', 'NnBnN'),
#  ('G6', 'G2', 'nnBGn'),
#  ('G1', 'G0', 'nnnnn'),
#  ('K4', 'K3', 'nnngn'),
#  ('G5', 'F9', 'nCnnn'),
#  ('G4', '00', 'VnnnR'),
#  ('G6', '00', 'VCnnR'),
#  ('NA', '00', 'HnnnB'),
#  (' sdM', 'M1', 'NCnnR'),
#  ('  dK', 'CV', 'nnnnN'),
#  ('K2', 'CAR', 'nnnnX'),
#  ('G8', 'F9', 'nnnGn'),
#  ('K7', 'F9', 'NnnnN'),
#  ('NA', '00', 'VCnnX'),
#  ('NA', 'A0', 'Dnnnn'),
#  ('K4', 'K3', 'nCnnn'),
#  ('NA', 'L5.5', 'NnBnN'),
#  ('K4', 'F9', 'nnBgn'),
#  ('G2', 'F2', 'nnnnn'),
#  ('M2', '00', 'VCnnN'),
#  ('NA', 'G2', 'nnBnn'),
#  ('NA', 'CV', 'NCnnR'),
#  ('K2', 'G5', 'nCnnn'),
#  ('NA', 'STARFORMING', 'VnnnN'),
#  ('M0', 'K7', 'NCnnX'),
#  ('NA', 'F9', 'nnnnn'),
#  ('G3', 'G2', 'nCBnn'),
#  ('NA', 'L5', 'NCnnN'),
#  ('G3', 'G2', 'nCnnn'),
#  ('K4', 'K5', 'NnnnN'),
#  ('NA', 'O', 'HnnnB'),
#  (' sdK', 'M0', 'nnnGn'),
#  ('G0', '00', 'VnnnX'),
#  ('K4', 'CAR', 'nnnnn'),
#  ('G7', 'F9', 'nnBnn'),
#  ('  dM', 'M3', 'nnnGn'),
#  ('F8', 'G2', 'nnnGn'),
#  ('  dK', 'M4', 'nnBnn'),
#  ('  dK', 'M0', 'nnBgn'),
#  ('G5', 'G2', 'nnngn'),
#  ('NA', 'CWD', 'nnBnc'),
#  ('G3', 'M0', 'nnngn'),
#  ('F9', 'K5', 'NnnnN'),
#  ('K4', 'K5', 'NnBnN'),
#  ('NA', 'K1', 'NnBnN'),
#  ('G5', 'M0', 'NnnnR'),
#  ('G2', 'F9', 'nnBgn'),
#  ('G0', 'F2', 'nnnGn'),
#  ('K4', 'F9', 'NnBnN'),
#  ('K4', 'M3', 'nnnnN'),
#  ('F3', 'F5', 'nnnnN'),
#  ('esdK', 'L5.5', 'NCnnN'),
#  ('G9', 'F2', 'nnBnN'),
#  ('G4', 'T2', 'NnnnN'),
#  ('M1', 'K3', 'NnBnN'),
#  ('M1', 'K5', 'NnnnN'),
#  ('NA', 'F5', 'nnnnX'),
#  ('M5', '00', 'VnnnX'),
#  ('  dM', 'M3', 'nCnGn'),
#  ('NA', 'AGNBROADLINE', 'VCBnN'),
#  ('G5', '00', 'VCBnX'),
#  ('  dM', 'M1', 'lCnnR'),
#  ('K4', 'K3', 'nnBnn'),
#  ('G9', 'F9', 'NCnnN'),
#  ('G0', 'F9', 'nnnnn'),
#  ('K5', 'F9', 'NnBnN'),
#  ('esdK', 'M0V', 'NCnnN'),
#  ('  dM', 'M0', 'lnnGn'),
#  ('NA', 'F5', 'NnnnN'),
#  ('NA', 'CAR', 'NCBnN'),
#  ('F8', 'F9', 'nnnGn'),
#  ('G5', '00', 'VCnnR'),
#  ('NA', 'L9', 'NnnnR'),
#  ('K2', 'G5', 'NCnnN'),
#  ('  dM', 'M4', 'nCnnN'),
#  ('K4', 'G5', 'nnnnn'),
#  ('G9', 'F5', 'nnnnn'),
#  (' sdK', '00', 'VCnnN'),
#  ('  dM', 'M4', 'DnBnn'),
#  ('NA', 'A0p', 'nnBnN'),
#  ('M3', '00', 'VCnnN'),
#  ('G3', 'G2', 'nnBgn'),
#  ('NA', 'F9', 'nnnnN'),
#  ('M9', '00', 'VCnnX'),
#  ('usdK', 'T2', 'NCnnN'),
#  ('G1', 'F5', 'NCBnN'),
#  ('NA', 'O', 'hnBnB'),
#  ('K4', 'K1', 'nnngn'),
#  ('NA', 'STARBURSTBROADLINE', 'VnBnN'),
#  ('NA', 'F2', 'DCnnn'),
#  ('NA', 'OB', 'hnBnN'),
#  (' sdM', 'M1', 'lCnnR'),
#  ('NA', 'L9', 'lnnnR'),
#  (' sdM', 'M0', 'lnnnR'),
#  ('K7', 'K5', 'NnnnN'),
#  ('NA', 'CV', 'nnnnN'),
#  ('G6', 'K1', 'NnnnN'),
#  ('K1', '00', 'VnnnN'),
#  ('G8', 'K1', 'nnnnN'),
#  ('NA', 'STARFORMING', 'VnBnN'),
#  ('usdM', 'M0V', 'lnnnR'),
#  ('  dM', 'M8', 'NnnnR'),
#  ('NA', 'G0', 'nCnnn'),
#  ('G6', 'G0', 'nnngn'),
#  ('G0', 'G2', 'NnnnN'),
#  ('F5', 'F5', 'nCnnn'),
#  ('G7', 'QSO', 'EnnnX'),
#  ('K5', 'K5', 'nnngn'),
#  ('M2', 'Carbon_lines', 'nCnnR'),
#  ('G3', 'F9', 'nnBgn'),
#  ('F3', 'F5', 'nnnnn'),
#  ('F3', 'CV', 'nnBnN'),
#  ('  dM', '00', 'VnnnR'),
#  ('G5', '00', 'VnnnX'),
#  ('K0', 'K1', 'nnnGn'),
#  ('  dK', '00', 'VnnnX'),
#  ('  dM', 'M8', 'NCnnR'),
#  ('F3', 'F2', 'NnnnN'),
#  ('NA', 'STARBURSTBROADLINE', 'VnnnR'),
#  ('NA', 'F5', 'Nnnnn'),
#  ('L6', 'F9', 'NCnnR'),
#  ('K2', 'G5', 'nnnnn'),
#  ('  dK', '00', 'nCBnn'),
#  ('NA', 'OB', 'NCnnN'),
#  ('K4', 'K7', 'nnnnR'),
#  ('K2', 'G2', 'nnnnn'),
#  ('K7', 'K7', 'nnnnn'),
#  ('F1', '00', 'VnnnN'),
#  ('M8', 'M8', 'NnnnR'),
#  ('K2', 'M0', 'nnnnn'),
#  ('K7', 'F5', 'nnngn'),
#  ('NA', 'A0p', 'nnBnn'),
#  ('K4', '00', 'nCnnn'),
#  ('G0', '00', 'VnnnN'),
#  ('F8', 'F5', 'nnBnN'),
#  ('  dK', '00', 'nCnnN'),
#  ('K4', 'F9', 'nnnGn'),
#  ('K1', 'QSO', 'EnnnX'),
#  ('M8', 'M8', 'NCnnR'),
#  ('F1', 'CV', 'nnbnn'),
#  ('NA', 'A0', 'nCBnn'),
#  (' sdK', 'K7', 'NnnnR'),
#  ('NA', 'L9', 'NCnnR'),
#  ('NA', 'AGNBROADLINE', 'VCnnN'),
#  ('  dK', '00', 'VCnnN'),
#  ('NA', 'F5', 'NCnnN'),
#  ('G8', 'K1', 'nnnnn'),
#  ('M0', 'G5', 'NCnnn'),
#  ('G3', 'G0', 'nnnnn'),
#  (' sdM', 'M2', 'NnnnR'),
#  ('NA', 'WD', 'nnBnX'),
#  ('K4', 'K5', 'Nnnnc'),
#  ('  dM', 'M2', 'lnnnR'),
#  ('F5', 'F5', 'nCnnN'),
#  ('M5', 'M8', 'NCnnR'),
#  ('G9', 'F9', 'NCBnN'),
#  ('F0', '00', 'VCnnN'),
#  ('G4', 'CWD', 'NnnnN'),
#  ('NA', 'F9', 'nnBgn'),
#  ('G5', 'F2', 'NnBnN'),
#  ('F4', 'F5', 'nCnnN'),
#  ('G2', '00', 'VCnnN'),
#  ('NA', 'A0', 'NnnnN'),
#  ('  dM', 'M0', 'nnngn'),
#  ('NA', 'T2', 'nnnnc'),
#  ('NA', 'O', 'hnnnB'),
#  ('NA', 'K1', 'NCnnN'),
#  ('G3', 'F2', 'nnnnn'),
#  ('M9', 'M9', 'NnnnR'),
#  ('F6', 'F2', 'nnnnN'),
#  ('G6', 'F9', 'nnngn'),
#  ('  dM', 'M1', 'nCnnP'),
#  ('K3', 'K1', 'NCnnN'),
#  ('G0', 'G2', 'nnnnn'),
#  ('F7', '00', 'VCBnN'),
#  ('K2', 'G2', 'nnnnN'),
#  ('G6', 'G2', 'nnngn'),
#  ('G2', 'QSO', 'EnnnX'),
#  ('F9', 'F9', 'NnnnN'),
#  ('F9', 'F5', 'NnnnN'),
#  ('esdM', 'M0V', 'nnnnR'),
#  ('F8', 'K7', 'nnnnn'),
#  ('  dM', 'M2', 'nCnnN'),
#  ('NA', 'CWD', 'nnnnN'),
#  ('esdK', 'CAR', 'lCnnR'),
#  ('NA', 'STARFORMING', 'nnBnN'),
#  ('F8', 'F5', 'nnBnn'),
#  ('  dK', '00', 'nCnnn'),
#  ('  dK', 'M2', 'NnnnN'),
#  ('  dM', 'M2', 'nnBgn'),
#  ('K4', '00', 'VCnnR'),
#  ('NA', 'A0', 'nnnnB'),
#  ('esdK', 'K7', 'nnngn'),
#  ('NA', 'WD', 'NnBnB'),
#  ('L2', 'M8', 'NCnnR'),
#  ('  dM', 'M1', 'lnnnR'),
#  ('NA', 'A0', 'nCBnN'),
#  ('  dK', 'L9', 'NnBnN'),
#  ('NA', 'G0', 'NnBnN'),
#  ('K0', 'F5', 'nnnnn'),
#  ('NA', 'M2', 'NCBnN'),
#  ('G2', 'G0', 'nCnnn'),
#  ('M0', 'G5', 'NCnnN'),
#  ('NA', 'WD', 'NCBnN'),
#  ('G3', 'G0', 'nCngn'),
#  ('K5', 'K5', 'NnnnN'),
#  (' sdM', 'M1', 'NnnnN'),
#  ('NA', 'A0p', 'hnnnX'),
#  ('K4', 'K5', 'nCBnP'),
#  ('G7', 'F2', 'NnBnN'),
#  ('NA', 'AGNBROADLINE', 'VnBnN'),
#  ('NA', 'WD', 'nnnnX'),
#  ('K7', 'F9', 'NnBnN'),
#  ('K4', '00', 'VCBnN'),
#  ('F4', 'F5', 'nCnnn'),
#  ('G6', 'M0', 'nnnnR'),
#  ('usdM', '00', 'VnnnR'),
#  ('M2', '00', 'VCnnR'),
#  ('  dK', 'K7', 'nnngn'),
#  ('F6', 'F2', 'nnnnn'),
#  ('F8', '00', 'nnBnc'),
#  ('F2', 'F5', 'nCnnN'),
#  ('F8', '00', 'VCnnX'),
#  ('K0', 'K5', 'nnnnn'),
#  ('NA', 'F9', 'NnnnN'),
#  ('G8', 'F9', 'nCBnn'),
#  ('F5', 'F5', 'nnnGn'),
#  ('K2', '00', 'nnngn'),
#  ('  dM', 'M4', 'Dnnnn'),
#  ('M9', 'M8', 'NnnnR'),
#  ('K2', 'G0', 'nnnnn'),
#  ('F2', 'F5', 'NCnnN'),
#  ('NA', 'M8', 'lnnnR'),
#  ('F9', '00', 'VnnnR'),
#  ('K2', 'F5', 'nnnnn'),
#  ('  dK', 'M0', 'nCnnP'),
#  ('K0', '00', 'VnnnN'),
#  ('F5', '00', 'VCBnN'),
#  ('NA', 'STARFORMING', 'VCnnX'),
#  ('G3', 'F9', 'nnnGn'),
#  ('G3', 'M0', 'lnnnR'),
#  ('F5', 'G0', 'nnnGn'),
#  ('G3', 'F5', 'nCngn'),
#  ('M6', 'QSO', 'EnnnX'),
#  ('  dK', 'M0', 'NnnGn'),
#  ('usdK', '00', 'VnBnN'),
#  ('M0', 'K1', 'nnnnn'),
#  ('NA', 'WD', 'hnnnB'),
#  ('M0', 'K3', 'NCBnN'),
#  ('G8', 'G0', 'nnngn'),
#  ('NA', 'STARFORMING', 'VnBnX'),
#  ('  dK', 'K3', 'nCnnn'),
#  ('F7', 'F5', 'nCnnn'),
#  ('K4', 'CAR', 'NnnnN'),
#  ('F6', 'F5', 'NnBnN'),
#  ('  dK', 'M1', 'nnngn'),
#  ('  dM', '00', 'VCnnN'),
#  ('K7', 'K7', 'nCnnn'),
#  ('K4', 'K3', 'nCBnn'),
#  ('K0', '00', 'VnnnX'),
#  ('F7', 'B6', 'NnnnN'),
#  ('K4', 'K5', 'nCngn'),
#  ('G8', 'G2', 'nCnnn'),
#  ('K5', 'K5', 'Nnnnn'),
#  ('esdK', 'M0V', 'NCnnR'),
#  ('NA', 'K5', 'NCnnN'),
#  ('  dM', 'M3', 'lCnnR'),
#  ('K4', 'T2', 'NCnnN'),
#  ('K4', 'K1', 'NnBnn'),
#  ('NA', 'M2', 'NCnnN'),
#  ('G6', 'K1', 'nCnnn'),
#  ('G9', 'K1', 'nnnnn'),
#  ('K0', 'QSO', 'EnnnX'),
#  ('  dM', 'M4', 'nCnnR'),
#  ('K4', 'K7', 'Nnnnn'),
#  ('M1', '00', 'VnnnN'),
#  ('  dK', 'M4', 'nCBnn'),
#  ('F2', 'F5', 'nCnnn'),
#  ('F8', '00', 'VnnnN'),
#  ('G3', 'G2', 'nnngn'),
#  ('G3', 'F9', 'NnnnN'),
#  ('NA', 'WD', 'hCnnN'),
#  ('G9', 'QSO', 'EnnnX'),
#  ('  dK', 'M2V', 'NCnnN'),
#  (' sdK', 'M0', 'NCnnN'),
#  ('  dM', 'M1', 'NCnnN'),
#  ('  dK', '00', 'VnBnN'),
#  ('NA', 'STARFORMING', 'nnBnX'),
#  ('M4', 'M7', 'nnnnn'),
#  ('K2', 'F5', 'nnnnN'),
#  ('M0', 'K3', 'nnnnn'),
#  ('NA', 'CV', 'nnbnn'),
#  ('NA', 'M8', 'VCnnR'),
#  ('NA', 'G2', 'nnnnX'),
#  ('K2', 'F5', 'nnngn'),
#  ('K2', 'G2', 'nnBnN'),
#  ('NA', 'AGN', 'lnnnN'),
#  ('F8', 'G0', 'nCnnn'),
#  ('F9', '00', 'VCBnN'),
#  ('  dM', 'M4', 'nnnnR'),
#  ('NA', 'M0', 'NCBnN'),
#  ('  dM', '00', 'VnBnX'),
#  ('  dK', '00', 'VCnnX'),
#  ('G6', 'K1', 'nnnnn'),
#  ('  dM', 'M2', 'NCnnN'),
#  ('M0', 'L5.5', 'NCnnN'),
#  ('NA', 'L5', 'VnnnR'),
#  ('G0', 'F5', 'NnnnN'),
#  ('esdK', '00', 'VnnnX'),
#  ('  dK', 'T2', 'NCBnN'),
#  ('esdK', 'K7', 'nnnnR'),
#  ('NA', 'WD', 'HnBnB'),
#  ('G2', 'G2', 'nnngn'),
#  ('K4', 'F9', 'NnnnN'),
#  ('  dK', 'M5', 'DnBnn'),
#  ('NA', 'B9', 'nnnnB'),
#  ('NA', 'M5', 'NnBnN'),
#  ('NA', 'L0', 'NCnnN'),
#  ('K0', 'F9', 'nnBGn'),
#  ('NA', 'L2', 'NCnnR'),
#  ('NA', 'OB', 'hCnnX'),
#  ('NA', 'L1', 'NCnnR'),
#  ('G7', 'G2', 'nnnGn'),
#  ('  dK', 'M6', 'nnnnn'),
#  ('K3', 'K1', 'NnBnN'),
#  ('NA', 'M0V', 'VnnnR'),
#  ('K3', '00', 'VCBnN'),
#  ('K4', 'K1', 'NnBnN'),
#  ('  dK', '00', 'nnBnn'),
#  ('esdM', 'M2V', 'NCnnR'),
#  ('M0', 'K5', 'nnnnR'),
#  ('esdK', 'K7', 'VnnnN'),
#  ('  dM', 'M1', 'nnnnc'),
#  ('G3', 'F5', 'nnngn'),
#  ('esdK', 'K7', 'NnnnR'),
#  ('K4', 'K7', 'NnnnN'),
#  ('  dM', 'M6', 'nCnnR'),
#  ('G6', '00', 'VnBnX'),
#  ('G9', 'K1', 'nnBnn'),
#  ('NA', 'STARFORMING', 'VCnnN'),
#  ('G9', 'G2', 'NnBnN'),
#  ('  dK', 'M0', 'nnnnX'),
#  ('K4', 'K3', 'nnnGn'),
#  ('G9', 'K3', 'nnnnn'),
#  ('K4', 'K7', 'nnngn'),
#  ('K0', 'K3', 'nnBnn'),
#  ('G6', 'G2', 'nnnnN'),
#  ('F8', 'G2', 'nCnnn'),
#  ('NA', 'B6', 'nnnnB'),
#  ('K2', 'K3', 'nnBnn'),
#  (' sdK', 'K7', 'NnnnN'),
#  (' sdK', 'M1', 'NCnnR'),
#  ('K5', 'K7', 'nnnnn'),
#  ('F2', 'F5', 'nnnnn'),
#  ('G9', 'K1', 'nnBgn'),
#  ('G1', '00', 'VnBnN'),
#  ('M8', 'M9', 'NCnnR'),
#  ('NA', 'L4', 'NCnnN'),
#  ('  dK', 'M0', 'NCnnn'),
#  ('G4', 'F5', 'NCBnN'),
#  ('G9', '00', 'VCBnN'),
#  ('G4', 'F9', 'nnngn'),
#  ('  dM', 'M1', 'nCnnR'),
#  ('NA', 'T2', 'lCnnR'),
#  ('M4', '00', 'VCnnX'),
#  ('NA', 'O', 'Dnnnn'),
#  ('F4', 'F5', 'nnnnn'),
#  ('esdK', '00', 'VCBnN'),
#  ('G5', 'G2', 'nnBnn'),
#  ('K4', 'L0', 'Nnnnc'),
#  ('K0', 'F9', 'nnBnn'),
#  ('esdK', 'T2', 'NnnnR'),
#  ('NA', 'A0', 'NCnnN'),
#  ('NA', 'F5', 'nnnnn'),
#  (' sdK', 'Carbon_lines', 'NnnnR'),
#  ('NA', 'L9', 'nnnnc'),
#  ('NA', 'B6', 'VCBnN'),
#  ('NA', 'F2', 'NnnnN'),
#  ('G3', 'G0', 'nnngn'),
#  ('F8', 'G0', 'NnnnN'),
#  ('NA', 'WD', 'nnnnN'),
#  ('K4', '00', 'VCBnX'),
#  ('G3', 'F5', 'nnnnn'),
#  ('NA', 'STARBURSTBROADLINE', 'VnnnN'),
#  ('  dK', 'M1', 'NnnnR'),
#  ('G5', 'F5', 'NnnnN'),
#  ('NA', 'A0p', 'nCBnB'),
#  ('  dM', 'M2', 'lCnnR'),
#  ('K3', 'F9', 'NnBnN'),
#  ('  dK', '00', 'nnnnn'),
#  ('G6', 'G0', 'NCBnN'),
#  ('NA', 'T2', 'NCnnN'),
#  ('NA', 'L5.5', 'NCBnN'),
#  ('F2', 'QSO', 'EnnnX'),
#  ('F8', 'T2', 'NnnnN'),
#  ('M6', 'M7', 'NCnnR'),
#  ('G6', 'G2', 'nnnnn'),
#  ('F8', 'G2', 'nCnnN'),
#  ('F8', 'F9', 'NnBnN'),
#  ('K2', 'K3', 'nnBnN'),
#  ('NA', 'A0', 'nnngn'),
#  ('F2', '00', 'VnnnR'),
#  ('NA', 'L9', 'NCnnN'),
#  ('F8', 'QSO', 'EnnnX'),
#  ('G0', 'K3', 'nnBnN'),
#  ('F2', 'F5', 'nnnnN'),
#  ('NA', 'STARFORMING', 'nnnnX'),
#  ('G0', 'F5', 'nnnGn'),
#  ('esdK', '00', 'VnnnN'),
#  ('  dK', 'M0', 'NCnnN'),
#  ('F8', 'B6', 'nnnnN'),
#  ('F3', '00', 'VCnnN'),
#  ('NA', 'WD', 'nCBnB'),
#  ('F4', 'F5', 'nnnnN'),
#  ('G3', 'F9', 'nnBnn'),
#  ('K2', 'G0', 'NnBnN'),
#  ('G3', 'G2', 'nnnnN'),
#  ('NA', 'F5', 'nnnnN'),
#  ('G0', 'F9', 'NnnnN'),
#  ('F5', 'F5', 'nnnnN'),
#  ('F8', 'F2', 'nnnGn'),
#  ('G5', '00', 'VCBnN'),
#  ('F6', '00', 'VnnnN'),
#  ('NA', 'K1', 'NCBnN'),
#  ('G4', 'G2', 'nnngn'),
#  ('K4', 'K5', 'nnngn'),
#  ('usdK', 'QSO', 'EnnnX'),
#  ('G6', 'K1', 'NCBnN'),
#  ('NA', 'WD', 'nnnnn'),
#  ('G8', '00', 'VnBnN'),
#  ('NA', 'CV', 'NnBnN'),
#  ('G9', 'K7', 'NnnnN'),
#  ('NA', 'A0p', 'NnnnN'),
#  ('K2', 'K1', 'NCnnn'),
#  ('G3', 'F5', 'nnnnN'),
#  ('L0', 'M9', 'NnnnR'),
#  ('  dM', 'M4', 'lnnnR'),
#  (' sdK', '00', 'VCnnX'),
#  ('G2', 'F9', 'nnnGn'),
#  ('F4', 'F5', 'NnnnN'),
#  ('M0', 'F9', 'nCBnn'),
#  ('K0', 'K3', 'NnBnn'),
#  ('F8', '00', 'VnnnX'),
#  ('M9', '00', 'VCnnR'),
#  ('F8', 'F5', 'Nnnnn'),
#  ('NA', 'WDmagnetic', 'NCBnN'),
#  ('G6', '00', 'VnnnR'),
#  ('K1', 'F9', 'NnnnN'),
#  ('  dM', 'M4', 'NnnnR'),
#  ('NA', 'L4', 'NnBnN'),
#  ('NA', 'SKY', 'Snnnn'),
#  (' sdK', 'M1', 'lCnnR'),
#  ('  dK', 'K5', 'NCnnN'),
#  ('NA', 'WD', 'NnBnN'),
#  ('G9', '00', 'VCBnX'),
#  ('K4', '00', 'nCBnN'),
#  ('K4', 'K3', 'nnBgn'),
#  ('K1', 'K3', 'NnnnN'),
#  ('esdK', '00', 'VCBnX'),
#  ('NA', 'T2', 'NCBnN'),
#  ('K2', 'K1', 'NnnnN'),
#  ('F8', '00', 'nnBnN'),
#  ('F7', '00', 'VCnnR'),
#  ('G5', 'G0', 'nnngn'),
#  ('NA', 'WDmagnetic', 'nnnnc'),
#  ('M2', 'K3', 'NnnnN'),
#  ('K7', 'K3', 'NnBnN'),
#  ('G4', 'F2', 'NnBnN'),
#  ('G2', 'F9', 'nnBnn'),
#  ('K2', 'F9', 'NnBnN'),
#  ('G3', 'F9', 'nnBnN'),
#  ('NA', 'L5', 'NnBnN'),
#  ('NA', '00', 'lnnnR'),
#  ('NA', 'M8', 'NnnnR'),
#  ('esdM', '00', 'VnnnR'),
#  ('esdK', 'QSO', 'EnnnX'),
#  ('  dK', '00', 'VnnnR'),
#  ('K4', 'K7', 'nnBnn'),
#  ('NA', 'F5', 'nnBnn'),
#  ('esdK', '00', 'VnBnN'),
#  ('NA', 'G0', 'nnnnn'),
#  ('NA', 'STARBURSTBROADLINE', 'VnnnX'),
#  (' sdM', 'M2V', 'lCnnR'),
#  ('M1', '00', 'VnnnR'),
#  ('M0', 'CAR', 'nnnnn'),
#  ('G4', 'G5', 'NnBnN'),
#  ('NA', 'L5.5', 'NCnnN'),
#  ('NA', 'STARFORMINGBROADLINE', 'VCBnX'),
#  ('  dK', 'M2', 'nnnnn'),
#  ('M0', 'F5', 'NnnnN'),
#  ('  dK', 'K7', 'nnnnN'),
#  ('NA', 'M3', 'NCnnN'),
#  ('G5', 'G2', 'nnnGn'),
#  ('usdK', '00', 'VCnnN'),
#  ('K7', 'K3', 'nnnnn'),
#  ('NA', 'G5', 'NnBnN'),
#  (' sdM', 'M0V', 'NnnnR'),
#  ('G5', 'F2', 'nnnnn'),
#  ('  dM', 'M3', 'nCnnc'),
#  ('K2', 'K1', 'nCBnn'),
#  ('K2', 'G2', 'nnBgn'),
#  ('NA', 'WD', 'NnnnN'),
#  ('F7', 'G0', 'nnnnn'),
#  ('G4', 'G0', 'nnngn'),
#  ('G6', 'M4', 'NnnnN'),
#  ('G6', '00', 'nCnnN'),
#  ('K0', 'K1', 'nnBnn'),
#  ('NA', 'WD', 'hnnnN'),
#  ('K0', 'F2', 'nnnnn'),
#  ('G2', 'G2', 'nnBnn'),
#  ('G3', 'G2', 'nnnGn'),
#  ('G6', 'F9', 'nnnGn'),
#  ('esdK', 'K7', 'nnnnn'),
#  ('G0', 'F9', 'nCnnn'),
#  ('M0', 'T2', 'NnnnN'),
#  ('K2', 'K5', 'nnnnn'),
#  ('  dM', 'M0', 'lCnnN'),
#  ('  dM', 'M6', 'lnnnR'),
#  ('K2', 'K1', 'NnBnN'),
#  ('NA', 'L2', 'VnnnN'),
#  ('NA', 'G0', 'NCnnN'),
#  ('F8', '00', 'nnnnN'),
#  ('F9', 'K7', 'NCnnN'),
#  ('K0', 'K3', 'nnnnn'),
#  ('K1', 'F9', 'nnnnn'),
#  ('G3', '00', 'VCBnX'),
#  (' sdK', 'CAR', 'nnnnR'),
#  ('M0', 'K5', 'nnnnN'),
#  ('G6', 'G0', 'nCngn'),
#  ('M4', '00', 'VnnnR'),
#  ('K2', 'K7', 'nCnnN'),
#  ('NA', 'F5', 'nnBnN'),
#  ('K4', '00', 'VnnnR'),
#  ('NA', 'G0', 'nnnnN'),
#  ('K2', 'F5', 'NnnnN'),
#  ('NA', 'K3', 'NnBnN'),
#  ('NA', 'B6', 'hnBnN'),
#  ('  dK', 'CV', 'NnnnN'),
#  ('G1', 'F5', 'NnnnN'),
#  ('G2', 'G0', 'nnnGn'),
#  ('esdK', 'K5', 'NnnnN'),
#  ('NA', '00', 'NCnnN'),
#  ('M3', 'M3', 'NCnnR'),
#  ('G3', '00', 'NnBnN'),
#  ('  dK', 'K7', 'nnnnn'),
#  ('  dM', 'M1', 'nnnGn'),
#  ('M0', 'K5', 'nnngn'),
#  ('G3', 'G2', 'nnnnn'),
#  ('K4', 'L5.5', 'NnBnN'),
#  ('F2', 'K5', 'NnnnN'),
#  ('K3', 'Carbon_lines', 'NnnnN'),
#  ('NA', 'F9', 'nCnnn'),
#  ('F8', 'F5', 'nnBgn'),
#  ('G6', 'F9', 'nnBGn'),
#  ('F8', 'F5', 'nCBnN'),
#  ('G6', 'F5', 'NnnnN'),
#  ('G4', '00', 'VCBnX'),
#  ('NA', 'T2', 'nnnnN'),
#  ('NA', 'L9', 'VCnnN'),
#  (' sdK', 'K5', 'NnnnN'),
#  ('M9', 'M9', 'NCnnR'),
#  ('G9', 'CV', 'NnBnN'),
#  ('NA', 'L4', 'nnBnN'),
#  ('K1', 'K5', 'NnnnN'),
#  ('K0', 'K1', 'nnngn'),
#  ('  dK', 'T2', 'NCnnN'),
#  ('  dM', 'M0', 'NCnnR'),
#  ('M2', '00', 'VnnnR'),
#  ('F8', 'K3', 'nnngn'),
#  ('M0', '00', 'nCnnn'),
#  ('K0', 'K1', 'nnnnn'),
#  ('F9', 'G2', 'NnnnN'),
#  ('G6', '00', 'VCnnN'),
#  ('  dK', 'M1', 'nnnnn'),
#  ('  dK', 'M1', 'nCnnn'),
#  ('K2', 'K1', 'NnBnn'),
#  ('F5', 'F5', 'nnnnX'),
#  ('G9', 'K1', 'nCBnn'),
#  ('NA', 'T2', 'VnnnR'),
#  ('G6', 'F5', 'nnnnN'),
#  ('NA', 'K7', 'NnnnN'),
#  ('G0', 'G0', 'nnngn'),
#  ('K3', '00', 'VCnnN'),
#  ('M2', 'F5', 'nnBnn'),
#  ('M0', '00', 'nnnnn'),
#  ('esdM', 'M0V', 'NnnnR'),
#  ('M0', 'K5', 'nnnnn'),
#  ('G1', 'F2', 'nnngn'),
#  ('G8', 'G2', 'nnnGn'),
#  ('esdK', 'K7', 'NnnnN'),
#  ('NA', 'STARBURSTBROADLINE', 'VCnnN'),
#  ('K3', 'K5', 'nnnnn'),
#  ('G6', 'F9', 'nnBnn'),
#  ('G3', 'F2', 'nnnGn'),
#  ('  dM', 'M7', 'nnnnc'),
#  ('K2', 'G0', 'nnBgn'),
#  ('esdK', 'K5', 'Nnnnn'),
#  ('K4', 'K3', 'NCnnN'),
#  ('G6', '00', 'VnnnX'),
#  ('NA', 'G2', 'nnnnn'),
#  ('L3', 'L2', 'NnnnR'),
#  ('M0', '00', 'VnnnR'),
#  ('  dK', 'K7', 'nCnnn'),
#  ('F0', 'CV', 'nnbnn'),
#  ('usdK', '00', 'VnBnX'),
#  ('K2', 'F2', 'nnnnN'),
#  ('G0', 'F2', 'nnngn'),
#  ('G5', 'F9', 'nnBgn'),
#  ('NA', 'CAR', 'VCBnN'),
#  ('F3', 'QSO', 'EnnnX'),
#  ('NA', 'K3', 'nnnnn'),
#  ('G4', 'F9', 'NnnnN'),
#  ('K0', '00', 'VnnnR'),
#  ('G5', 'G2', 'nnBgn'),
#  ('M2', '00', 'VCBnN'),
#  ('G9', '00', 'VCnnX'),
#  ('G8', 'K3', 'NnnnN'),
#  (' sdM', 'M0', 'NnnnN'),
#  ('F8', 'F5', 'NCnnN'),
#  ('M0', 'K3', 'NnBnN'),
#  ('M2', 'K7', 'NnnnN'),
#  ('M7', 'M9', 'NCnnR'),
#  ('  dK', 'M1', 'nCnnN'),
#  ('NA', '00', 'VCBnX'),
#  ('F7', '00', 'VnBnN'),
#  ('G6', 'F5', 'nnnnn'),
#  ('K2', 'G2', 'nnnGn'),
#  ('M0', '00', 'nnnnN'),
#  ('G6', 'F5', 'nnngn'),
#  ('G2', 'F5', 'nnngn'),
#  ('G9', 'G5', 'NnnnN'),
#  ('F5', 'T2', 'NnnnN'),
#  ('NA', 'M1', 'VCnnR'),
#  ('M3', 'T2', 'NCnnR'),
#  ('NA', 'CV', 'NnnnR'),
#  ('esdM', 'M2V', 'NnnnR'),
#  ('NA', 'STARBURSTBROADLINE', 'VCnnR'),
#  ('  dM', 'M4', 'DCnnn'),
#  ('M0', 'K7', 'nnBnN'),
#  ('  dM', 'M3', 'DCBnP'),
#  ('NA', 'G2', 'nnnnN'),
#  ('G9', 'F9', 'nnngn'),
#  ('G7', 'G2', 'nnngn'),
#  ('NA', 'Carbon_lines', 'NCBnN'),
#  ('  dK', 'K7', 'nCnnN'),
#  ('K2', 'K3', 'NnnnN'),
#  ('  dK', 'M2', 'nCnnn'),
#  ('K2', 'F2', 'nnnnn'),
#  ('  dM', 'M1', 'nCBnN'),
#  ('esdK', '00', 'VnnnR'),
#  ('L1', 'L2', 'NCnnR'),
#  ('G9', '00', 'VnnnR'),
#  ('NA', 'WD', 'nCBnN'),
#  ('F8', 'G2', 'NnnnN'),
#  ('  dK', 'K7', 'lnnnn'),
#  ('G3', 'F5', 'NnnnN'),
#  (' sdK', 'K7', 'lnnnn'),
#  ('M0', 'F9', 'NnBnN'),
#  ('NA', 'OB', 'hCnnN'),
#  ('K4', 'G5', 'nnngn'),
#  ('NA', 'CAR', 'NnnnN'),
#  ('F9', 'Carbon_lines', 'NCnnN'),
#  ('K1', '00', 'VnBnN'),
#  ('NA', 'CWD', 'nnBnN'),
#  ('NA', 'M5', 'NCnnN'),
#  ('M0', 'M1', 'Dnnnn'),
#  ('F8', 'F2', 'nCnnn'),
#  ('NA', 'M3', 'NCnnR'),
#  ('  dK', 'K7', 'Nnnnn'),
#  ('NA', 'M4', 'NCnnR'),
#  ('G1', 'F9', 'nCnnn'),
#  ('G1', 'T2', 'NnnnN'),
#  ('F8', 'CWD', 'nnBnX'),
#  ('K1', '00', 'VCnnN'),
#  ('  dM', 'M5', 'nCnnR'),
#  ('F8', 'G2', 'nnnnN'),
#  ('esdK', 'K1', 'NCnnN'),
#  ('M3', 'QSO', 'EnnnX'),
#  ('NA', 'M6', 'NCnnN'),
#  ('  dM', 'M3', 'NCnnR'),
#  ('  dK', 'M0', 'nCnnn'),
#  ('G4', '00', 'VnnnX'),
#  ('F8', 'G2', 'nnngn'),
#  ('G8', 'G2', 'nnBgn'),
#  ('NA', 'STARFORMING', 'nnnnn'),
#  ('  dK', 'M2', 'NCnnN'),
#  ('G8', '00', 'VnnnX'),
#  ('G5', 'G2', 'NnnnN'),
#  ('  dM', 'M5', 'nnnnn'),
#  ('NA', 'AGN', 'lnnnX'),
#  ('L6', '00', 'VCBnN'),
#  ('K2', 'K3', 'nCngn'),
#  ('M4', 'M4', 'NnnnR'),
#  ('M4', '00', 'VCnnR'),
#  ('G0', 'F5', 'nnBnn'),
#  ('K4', '00', 'VnBnN'),
#  ('NA', 'WD', 'nCnnn'),
#  ('K0', 'K5', 'NnnnN'),
#  ('K0', '00', 'VCBnX'),
#  ('NA', '00', 'hnBnB'),
#  ('NA', 'WD', 'nCBnn'),
#  ('NA', 'F9', 'nnngn'),
#  ('esdM', 'M0V', 'NCnnR'),
#  ('NA', 'F5', 'nCnnn'),
#  ('K2', 'K3', 'NCnnn'),
#  ('G6', 'QSO', 'EnnnX'),
#  ('NA', 'WDmagnetic', 'nCBnN'),
#  ('K5', '00', 'VnnnX'),
#  ('F8', '00', 'VnBnX'),
#  ('M4', '00', 'VnnnN'),
#  ('L7', '00', 'VnnnR'),
#  ('  dM', 'M1', 'nnnnR'),
#  ('G8', 'B9', 'nnnnN'),
#  ('G8', 'QSO', 'EnnnX'),
#  ('F8', 'G0', 'nnnnN'),
#  ('G0', 'G0', 'nnnnn'),
#  (' sdM', 'M2V', 'NnnnR'),
#  ('F9', 'F5', 'NCnnN'),
#  ('M0', 'CAR', 'nnnnR'),
#  ('NA', 'STARFORMING', 'VCBnN'),
#  ('NA', 'L5.5', 'NCnnR'),
#  ('K2', 'F5', 'nnnGn'),
#  ('K2', 'F9', 'nCngn'),
#  ('  dK', 'K7', 'NnnnN'),
#  ('G5', 'F9', 'nnnGn'),
#  ('K5', 'K7', 'nCnnn'),
#  ('K2', 'F9', 'nnnnn'),
#  ('K0', 'G2', 'nnnnn'),
#  ('F8', 'G2', 'nnnnn'),
#  ('K0', 'K1', 'nnBgn'),
#  ('G6', 'G2', 'nCnnn'),
#  ('K2', 'T2', 'NCnnN'),
#  ('G7', 'F5', 'NnnnN'),
#  ('G9', 'F9', 'nnBnn'),
#  ('M7', 'M7', 'NCnnR'),
#  ('F8', 'F2', 'nnngn'),
#  ('G6', '00', 'VCBnN'),
#  ('  dM', 'M6', 'nnnnR'),
#  ('G5', 'F2', 'nnngn'),
#  (' sdM', 'M2V', 'lnnnR'),
#  ('NA', 'WD', 'nnbnn'),
#  ('F9', 'F9', 'nnnnn'),
#  ('G6', 'G0', 'NnnnN'),
#  ('L2', 'L3', 'NCnnR'),
#  ('NA', 'M3', 'NnnnR'),
#  ('G1', '00', 'VnBnX'),
#  ('K4', 'K5', 'DnnGn'),
#  (' sdK', '00', 'VnnnN'),
#  ('M0', 'K5', 'nCnnn'),
#  (' sdK', 'K7', 'nnngn'),
#  ('NA', '00', 'VnBnX'),
#  ('NA', 'L5.5', 'hnBnN'),
#  ('  dM', 'L9', 'NCnnN'),
#  ('NA', 'WD', 'nCnnN'),
#  ('NA', 'K3', 'nnngn'),
#  ('G3', 'F5', 'nnnGn'),
#  ('G6', 'F2', 'nnBnN'),
#  ('M2', '00', 'VCBnX'),
#  ('  dM', 'M7', 'nnnnR'),
#  ('K5', '00', 'VCBnN'),
#  ('F7', 'F5', 'nnnnN'),
#  ('M0', '00', 'NnnnN'),
#  ('NA', '00', 'VCBnN'),
#  ('F8', 'G0', 'nnngn'),
#  ('K5', 'K5', 'nCnnn'),
#  ('NA', 'L9', 'nnBnX'),
#  ('G8', 'F9', 'NnnnN'),
#  ('F3', 'F5', 'nnnGn'),
#  ('NA', 'STARFORMING', 'NnBnN'),
#  ('K7', '00', 'VCnnR'),
#  ('  dM', 'M7', 'NCnnR'),
#  ('F8', 'G0', 'nnnnn'),
#  ('G3', 'F9', 'nnngn'),
#  ('NA', 'WD', 'DnBnn'),
#  ('K4', 'F5', 'NnBnN'),
#  ('NA', 'CV', 'NCnnN'),
#  ('G5', 'F9', 'nnngn'),
#  ('  dK', 'K5', 'NnnnR'),
#  ('NA', '00', 'hnnnN'),
#  ('M7', '00', 'VnnnR'),
#  ('  dM', 'M4', 'NCnnN'),
#  ('NA', 'F5', 'HCnnB'),
#  ('K2', 'F9', 'nnnnN'),
#  ('G5', 'F5', 'nnnnn'),
#  ('M6', 'M6', 'NCnnR'),
#  ('M0', '00', 'VCBnN'),
#  ('G8', 'G0', 'nnnGn'),
#  ('NA', 'CAR', 'NCnnN'),
#  ('  dK', 'K7', 'Nnngn'),
#  ('G3', 'G0', 'nnnGn'),
#  ('M0', '00', 'VCnnR'),
#  ('NA', 'F5', 'nnBnc'),
#  ('NA', 'M5', 'NnnnR'),
#  ('  dM', 'M3', 'nCBnN'),
#  ('G0', 'K7', 'NnnnN'),
#  ('F6', 'QSO', 'EnnnX'),
#  ('NA', 'M9', 'NCnnR'),
#  ('NA', 'M4', 'nnBnN'),
#  ('G6', 'F9', 'NCnnN'),
#  (' sdK', 'M0', 'nCBnn'),
#  ('K3', '00', 'VnnnR'),
#  ('K2', 'K1', 'NCBnn'),
#  ('NA', 'G2', 'nCnnB'),
#  ('NA', 'M0', 'NnnnN'),
#  ('NA', 'STARFORMING', 'VnnnX'),
#  ('M1', '00', 'VCnnR'),
#  ('usdK', 'M0', 'NnnnR'),
#  ('  dM', 'M2', 'nCnnc'),
#  ('K0', 'G2', 'NnnnN'),
#  ('G8', 'G2', 'nnnnn'),
#  ('K4', 'K1', 'NCBnN'),
#  ('L5', 'L4', 'NCnnR'),
#  ('NA', 'G0', 'NCBnN'),
#  ('  dM', 'M9', 'NCnnR'),
#  ('K7', 'L9', 'NnBnN'),
#  ('NA', 'T2', 'NnBnN'),
#  ('  dK', 'M4', 'NCnnN'),
#  ('NA', 'K7', 'nnnnN'),
#  ('K7', '00', 'VnnnX'),
#  ('F7', 'F5', 'nnnnn'),
#  ('M0', 'Carbon_lines', 'NCnnN'),
#  ('F7', '00', 'VnnnN'),
#  ('NA', 'B6', 'Dnnnn'),
#  ('M5', '00', 'VnnnR'),
#  ('G0', 'F5', 'nnngn'),
#  ('K2', 'K1', 'nnnnn'),
#  ('M0', 'F5', 'nnnnN'),
#  ('K2', 'K3', 'nnBgn'),
#  ('G5', 'F5', 'nnnnN'),
#  ('NA', 'STARFORMING', 'nCBnN'),
#  ('G0', 'G2', 'nnnGn'),
#  ...}

# %% [markdown]
# ## "Normal stars"
#
# Select only with flag nnnnn

# %%
# %time normalstars = np.unique([ i[28] for i in data[0:] if i[29] == 'nnnnn'   ],return_counts=True)
normalstars
# Out:
# CPU times: user 3min 17s, sys: 317 ms, total: 3min 17s
# Wall time: 3min 17s
# (array(['00', 'A0', 'A0p', 'AGNBROADLINE', 'B6', 'B9', 'CAR', 'CV', 'CWD',
#         'F2', 'F5', 'F9', 'G0', 'G2', 'G5', 'K1', 'K3', 'K5', 'K7', 'L5',
#         'L5.5', 'L9', 'M0', 'M0V', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7',
#         'M8', 'O', 'OB', 'STARFORMING', 'STARFORMINGBROADLINE', 'T2', 'WD',
#         'WDmagnetic'],
#        dtype='|S20'),
#  array([  358, 54512,   358,     1,    60,    45,    37,   214,     3,
#          8782, 79744, 87082,  6975, 17863,   927, 21511, 20685, 20140,
#          8160,     1,    11,    13,   528,     1,    69,    43,    54,
#            48,     7,     8,     5,     2,     5,     4,    87,     1,
#            19,  1149,     1]))
